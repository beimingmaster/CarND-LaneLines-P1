# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
#
# ## Project: **Finding Lane Lines on the Road**
# ***
# In this project, you will use the tools you learned about in the lesson to identify lane lines on the road.  You can develop your pipeline on a series of individual images, and later apply the result to a video stream (really just a series of images). Check out the video clip "raw-lines-example.mp4" (also contained in this repository) to see what the output should look like after using the helper functions below.
#
# Once you have a result that looks roughly like "raw-lines-example.mp4", you'll need to get creative and try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines.  You can see an example of the result you're going for in the video "P1_example.mp4".  Ultimately, you would like to draw just one line for the left side of the lane, and one for the right.
#
# In addition to implementing code, there is a brief writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) that can be used to guide the writing process. Completing both the code in the Ipython notebook and the writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/322/view) for this project.
#
# ---
# Let's have a look at our first image called 'test_images/solidWhiteRight.jpg'.  Run the 2 cells below (hit Shift-Enter or the "play" button above) to display the image.
#
# **Note: If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".**
#
# ---

# %% [markdown]
# **The tools you have are color selection, region of interest selection, grayscaling, Gaussian smoothing, Canny Edge Detection and Hough Tranform line detection.  You  are also free to explore and try other techniques that were not presented in the lesson.  Your goal is piece together a pipeline to detect the line segments in the image, then average/extrapolate them and draw them onto the image for display (as below).  Once you have a working pipeline, try it out on the video stream below.**
#
# ---
#
# <figure>
#  <img src="examples/line-segments-example.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above) after detecting line segments using the helper functions below </p>
#  </figcaption>
# </figure>
#  <p></p>
# <figure>
#  <img src="examples/laneLines_thirdPass.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your goal is to connect/average/extrapolate line segments to get output like this</p>
#  </figcaption>
# </figure>

# %% [markdown]
# **Run the cell below to import some packages.  If you get an `import error` for a package you've already installed, try changing your kernel (select the Kernel menu above --> Change Kernel).  Still have problems?  Try relaunching Jupyter Notebook from the terminal prompt.  Also, consult the forums for more troubleshooting tips.**

# %% [markdown]
# ## Import Packages

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %% [markdown]
# ## Read in an Image

# %%
#reading in an image
image = mpimg.imread('test_images/solidWhiteRight.jpg')

#printing out some stats and plotting
print('This image is:', type(image), 'with dimensions:', image.shape)
plt.imshow(image)  # if you wanted to show a single color channel image called 'gray', for example, call as plt.imshow(gray, cmap='gray')
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)

# %% [markdown]
# ## Ideas for Lane Detection Pipeline

# %% [markdown]
# **Some OpenCV functions (beyond those introduced in the lesson) that might be useful for this project are:**
#
# `cv2.inRange()` for color selection
# `cv2.fillPoly()` for regions selection
# `cv2.line()` to draw lines on an image given endpoints
# `cv2.addWeighted()` to coadd / overlay two images
# `cv2.cvtColor()` to grayscale or change color
# `cv2.imwrite()` to output images to file
# `cv2.bitwise_and()` to apply a mask to an image
#
# **Check out the OpenCV documentation to learn about these and discover even more awesome functionality!**

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# Below are some helper functions to help get you started. They should look familiar from the lesson!

# %%
import math

def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    (assuming your grayscaled image is called 'gray')
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Or use BGR2GRAY if you read an image with cv2.imread()
    # return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image


def draw_lines(img, lines, color=[255, 0, 0], thickness=10):
    """
    NOTE: this is the function you might want to use as a starting point once you want to 
    average/extrapolate the line segments you detect to map out the full
    extent of the lane (going from the result shown in raw-lines-example.mp4
    to that shown in P1_example.mp4).  
    
    Think about things like separating line segments by their 
    slope ((y2-y1)/(x2-x1)) to decide which segments are part of the left
    line vs. the right line.  Then, you can average the position of each of 
    the lines and extrapolate to the top and bottom of the lane.
    
    This function draws `lines` with `color` and `thickness`.    
    Lines are drawn on the image inplace (mutates the image).
    If you want to make the lines semi-transparent, think about combining
    this function with the weighted_img() function below
    """
    #print('line count: ', len(lines))
    left_line = lines[0]
    left_slop = 0
    right_line = lines[-1]
    right_slop = 0
    for line in lines:
        for x1,y1,x2,y2 in line:
            #cv2.line(img, (x1, y1), (x2, y2), color, thickness)
            #for interplote line;
            if abs(y2 - y1) > 30.0 and abs(x2-x1) > 0.000001:
                k = (y2-y1)/(x2-x1)
                b = y2 - k*x2
                if k > 0 and k < left_slop:
                    left_line = line
                    left_slop = k
                elif k < 0 and k > right_slop:
                    right_line = line
                    right_slop = k
                    
    lane_lines = [left_line, right_line]
    for line in lane_lines:
        for x1, y1, x2, y2 in line:
            cv2.line(img, (x1, y1), (x2, y2), color, thickness)
            if abs(y2 - y1) > 30.0 and abs(x2-x1) > 0.000001:
                k = (y2-y1)/(x2-x1)
                b = y2 - k*x2
                py = img.shape[0]
                px = int((py - b)/k)
                if y1 < y2:
                    cv2.line(img, (x1, y1), (px, py), color, thickness)
                else:
                    cv2.line(img, (x2, y2), (px, py), color, thickness)

def hough_lines(source_image, img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
    if lines is None:
        print('no lane lines!')
        return
    channel = 3
    shape = source_image.shape
    if len(shape) > 2:
        channel = shape[2]
    line_img = np.zeros((img.shape[0], img.shape[1], channel), dtype=np.uint8)
    draw_lines(line_img, lines)
    return line_img

# Python 3 has support for cool math symbols.

def weighted_img(img, initial_img, α=0.8, β=1., λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, λ)

# %% [markdown]
# ## Test Images
#
# Build your pipeline to work on the images in the directory "test_images"
# **You should make sure your pipeline works well on these images before you try the videos.**

# %%
import os

# %% [markdown]
# ## Build a Lane Finding Pipeline

# %% [markdown]
# Build the pipeline and run your solution on all test_images. Make copies into the `test_images_output` directory, and you can use the images in your writeup report.
#
# Try tuning the various parameters, especially the low and high Canny thresholds as well as the Hough lines parameters.

# %%
# TODO: Build your pipeline that will draw lane lines on the test_images
# then save them to the test_images directory.

#for algorithm's parameters
blur_kernel_size = 3
#normal images;
normal_canny_low_threshold = 50
normal_canny_high_threshold = 150
#challenge images;
challenge_canny_low_threshold = 150
challenge_canny_high_threshold = 250
mask_color = 255
hough_rho = 2
hough_theta = np.pi/180
# hough_threshold = 15
# normal_hough_min_line_length = 60
# challenge_hough_min_line_length = 90
# hough_max_line_gap =20
hough_threshold = 50
normal_hough_min_line_length = 100
challenge_hough_min_line_length = 100
hough_max_line_gap =160

save_flag = True

#for poly region ratio beacause different image size
ratio = 0.1111
poly_ratio_00 = 150.0/960
poly_ratio_10 = 430.0/960
poly_ratio_11 = 320.0/540
poly_ratio_20 = 550.0/960
poly_ratio_21 = 320.0/540
poly_ratio_30 = 950.0/960
_
def find_lane_lines(image, canny_low_threshold=normal_canny_low_threshold, canny_high_threshold=normal_canny_high_threshold, hough_min_line_length=normal_hough_min_line_length):
    gray = grayscale(image)
    blur_gray = gaussian_blur(gray, blur_kernel_size)
    edges = canny(blur_gray, canny_low_threshold, canny_high_threshold)
    imshape = image.shape
    #print('image shape: ', imshape)
    vertices = np.array([[(int(poly_ratio_00*imshape[1]),imshape[0]),(int(poly_ratio_10*imshape[1]), int(poly_ratio_11*imshape[0])), (int(poly_ratio_20*imshape[1]), int(poly_ratio_21*imshape[0])), (int(poly_ratio_30*imshape[1]),imshape[0])]], dtype=np.int32)
    masked_edges = region_of_interest(edges, vertices)
    line_image = hough_lines(image, masked_edges, hough_rho, hough_theta, hough_threshold, hough_min_line_length, hough_max_line_gap)
    #line_image = hough_lines(image, masked_edges, hough_rho, hough_theta, hough_threshold, ratio*imshape[0], hough_max_line_gap)
    if line_image is not None:
        #color_edges = np.dstack((edges, edges, edges))
        #print('masked edges shape: ', masked_edges.shape, ', line image shape: ', line_image.shape, ', image shape: ', image.shape)
        lines_edges = weighted_img(line_image, image)
        return lines_edges,masked_edges
    else:
        print('has error in %s' % image_file)

# %%
#for general images
image_list = os.listdir("test_images/")
print(image_list)

plt.figure(num='output', figsize=(16,16))

for i, image_file in enumerate(image_list):
    image = mpimg.imread('test_images/%s' % image_file)
    lines_edges,edges = find_lane_lines(image)
    if lines_edges is not None:
        print('lane lines of %s' % image_file)
        plt.subplot(3,2,i+1)
        plt.title('lane-lines for %s' % image_file)
        plt.imshow(lines_edges)
        if save_flag:
            output_file = 'test_images_output/%s' % image_file 
            mpimg.imsave(output_file, lines_edges)
    else:
        print('has error in %s' % image_file)
# Out:
# ['solidWhiteRight.jpg', 'whiteCarLaneSwitch.jpg', 'solidYellowLeft.jpg', 'solidYellowCurve2.jpg', 'solidWhiteCurve.jpg', 'solidYellowCurve.jpg']
# line count:  6
# lane lines of solidWhiteRight.jpg
# line count:  8
# lane lines of whiteCarLaneSwitch.jpg
# line count:  9
# lane lines of solidYellowLeft.jpg
# line count:  12
# lane lines of solidYellowCurve2.jpg
# line count:  8
# lane lines of solidWhiteCurve.jpg
# line count:  11
# lane lines of solidYellowCurve.jpg

# %%
#for challenge images
image_list = os.listdir("test_challenge_images/")
print(image_list)
plt.figure(num='output_challenge', figsize=(16,16)) 
for i, image_file in enumerate(image_list):
    image = mpimg.imread('test_challenge_images/%s' % image_file)
    lines_edges, edges = find_lane_lines(image, challenge_canny_low_threshold, challenge_canny_high_threshold, challenge_hough_min_line_length)
    if lines_edges is not None:
        print('lane lines of %s' % image_file)
        plt.subplot(3,2,i+1)
        plt.title('lane-lines for %s' % image_file)
        plt.imshow(lines_edges)
        if save_flag:
            output_file = 'test_challenge_images_output/%s' % image_file 
            #mpimg.imsave(output_file, lines_edges)
    else:
        print('has error in %s' % image_file)
# Out:
# ['00050.jpg', '00150.jpg', '00100.jpg', '00200.jpg', '00250.jpg']
# line count:  20
# lane lines of 00050.jpg
# line count:  18
# lane lines of 00150.jpg
# line count:  19
# lane lines of 00100.jpg
# line count:  19
# lane lines of 00200.jpg
# line count:  19
# lane lines of 00250.jpg

# %% [markdown]
# ## Test on Videos
#
# You know what's cooler than drawing lanes over images? Drawing lanes over video!
#
# We can test our solution on two provided videos:
#
# `solidWhiteRight.mp4`
#
# `solidYellowLeft.mp4`
#
# **Note: if you get an import error when you run the next cell, try changing your kernel (select the Kernel menu above --> Change Kernel). Still have problems? Try relaunching Jupyter Notebook from the terminal prompt. Also, consult the forums for more troubleshooting tips.**
#
# **If you get an error that looks like this:**
# ```
# NeedDownloadError: Need ffmpeg exe.
# You can download it by calling:
# imageio.plugins.ffmpeg.download()
# ```
# **Follow the instructions in the error message and check out [this forum post](https://discussions.udacity.com/t/project-error-of-test-on-videos/274082) for more troubleshooting tips across operating systems.**

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
count = 0
def process_image(image):
    global count
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image where lines are drawn on lanes)
    result,_ = find_lane_lines(image)
#     count = count + 1
#     if count % 50 == 0:
#         mpimg.imsave('test_challenge_images/%05d.jpg' % count, image)
    return result

# %% [markdown]
# Let's try the one with the solid white lane on the right first ...

# %%
#white_output = 'test_videos_output/solidWhiteRight.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4").subclip(0,5)
video_list = os.listdir("test_videos")
print(video_list)
for video_file in video_list:
    clip1 = VideoFileClip('test_videos/%s' % video_file)
    print('do processing: ', video_file)
    white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
    white_output = 'test_videos_output/%s' % video_file
    # %time white_clip.write_videofile(white_output, audio=False)
# Out:
# ['solidWhiteRight.mp4', 'solidYellowLeft.mp4', 'challenge.mp4']
# do processing:  solidWhiteRight.mp4
# line count:  13
# [MoviePy] >>>> Building video test_videos_output/solidWhiteRight.mp4
# [MoviePy] Writing video test_videos_output/solidWhiteRight.mp4
#   0%|          | 0/222 [00:00<?, ?it/s]
# line count:  13
# line count:  10
# line count:  7
#   5%|▍         | 11/222 [00:00<00:01, 105.79it/s]
# line count:  9
# line count:  7
# line count:  7
# line count:  6
# line count:  8
# line count:  9
# line count:  7
# line count:  9
# line count:  11
# line count:  8
# line count:  7
# line count:  8
# line count:  8
# line count:  6
# line count:  8
# line count:  9
# line count:  6
# line count:  7
# line count:  9
# line count:  7
#  11%|█         | 24/222 [00:00<00:01, 111.30it/s]
# line count:  11
# line count:  12
# line count:  10
# line count:  8
# line count:  9
# line count:  7
#  17%|█▋        | 37/222 [00:00<00:01, 115.54it/s]
# line count:  9
# line count:  7
# line count:  9
# line count:  10
# line count:  7
# line count:  10
# line count:  10
# line count:  11
# line count:  9
# line count:  10
# line count:  8
# line count:  7
# line count:  6
# line count:  7
# line count:  10
# line count:  9
# line count:  9
# line count:  9
#  21%|██        | 47/222 [00:00<00:01, 102.94it/s]
# line count:  11
# line count:  8
#  27%|██▋       | 59/222 [00:00<00:01, 105.48it/s]
# line count:  9
# line count:  11
# line count:  11
# line count:  11
# line count:  9
# line count:  10
# line count:  8
# line count:  7
# line count:  8
# line count:  11
# line count:  10
# line count:  7
# line count:  9
# line count:  9
# line count:  8
# line count:  7
# line count:  11
# line count:  7
# line count:  8
# line count:  7
#  32%|███▏      | 70/222 [00:00<00:01, 104.47it/s]
# line count:  9
# line count:  7
#  36%|███▋      | 81/222 [00:00<00:01, 105.71it/s]
# line count:  9
# line count:  6
# line count:  8
# line count:  9
# line count:  7
# line count:  7
# line count:  7
# line count:  8
# line count:  10
# line count:  7
# line count:  7
# line count:  7
# line count:  7
# line count:  7
# line count:  8
# line count:  7
# line count:  7
# line count:  8
# line count:  10
# line count:  7
# line count:  9
#  42%|████▏     | 93/222 [00:00<00:01, 107.85it/s]
# line count:  9
# line count:  7
#  47%|████▋     | 105/222 [00:00<00:01, 109.35it/s]
# line count:  7
# line count:  8
# line count:  10
# line count:  7
# line count:  7
# line count:  8
# line count:  7
# line count:  7
# line count:  8
# line count:  8
# line count:  8
# line count:  9
# line count:  6
# line count:  8
# line count:  9
# line count:  8
# line count:  9
# line count:  9
# line count:  9
# line count:  8
#  52%|█████▏    | 116/222 [00:01<00:00, 106.95it/s]
# line count:  9
# line count:  10
#  57%|█████▋    | 127/222 [00:01<00:00, 106.76it/s]
# line count:  11
# line count:  10
# line count:  8
# line count:  10
# line count:  10
# line count:  7
# line count:  9
# line count:  9
# line count:  7
# line count:  5
# line count:  8
# line count:  7
# line count:  7
# line count:  8
# line count:  10
# line count:  9
# line count:  9
# line count:  9
# line count:  10
# line count:  8
# line count:  6
#  67%|██████▋   | 149/222 [00:01<00:00, 102.06it/s]
# line count:  6
# line count:  8
# line count:  8
# line count:  9
# line count:  10
# line count:  9
# line count:  8
# line count:  8
# line count:  7
# line count:  8
# line count:  12
# line count:  10
# line count:  8
# line count:  8
# line count:  9
# line count:  9
# line count:  10
# line count:  11
# line count:  9
# line count:  9
# line count:  11
#  77%|███████▋  | 171/222 [00:01<00:00, 100.62it/s]
# line count:  8
# line count:  8
# line count:  10
# line count:  8
# line count:  11
# line count:  7
# line count:  7
# line count:  9
# line count:  8
# line count:  7
# line count:  9
# line count:  7
# line count:  10
# line count:  8
# line count:  10
# line count:  6
# line count:  8
# line count:  8
# line count:  9
# line count:  7
#  86%|████████▋ | 192/222 [00:01<00:00, 99.64it/s]
# line count:  9
# line count:  8
# line count:  8
# line count:  10
# line count:  9
# line count:  12
# line count:  11
# line count:  10
# line count:  9
# line count:  7
# line count:  7
# line count:  9
# line count:  8
# line count:  11
# line count:  10
# line count:  10
# line count:  9
# line count:  13
# line count:  9
# line count:  8
#  96%|█████████▌| 213/222 [00:02<00:00, 99.80it/s]
# line count:  8
# line count:  8
# line count:  9
# line count:  12
# line count:  10
# line count:  12
# line count:  12
# line count:  12
# line count:  8
# line count:  11
# line count:  7
# line count:  4
# line count:  7
# line count:  7
# line count:  8
# line count:  9
# line count:  8
# line count:  8
# line count:  9
# line count:  7
# line count:  9
# 100%|█████████▉| 221/222 [00:02<00:00, 104.32it/s]
# line count:  11
# line count:  9
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/solidWhiteRight.mp4
#
# CPU times: user 1.55 s, sys: 428 ms, total: 1.98 s
# Wall time: 2.36 s
# do processing:  solidYellowLeft.mp4
# line count:  9
# [MoviePy] >>>> Building video test_videos_output/solidYellowLeft.mp4
# [MoviePy] Writing video test_videos_output/solidYellowLeft.mp4
#   0%|          | 0/682 [00:00<?, ?it/s]
# line count:  9
# line count:  10
# line count:  8
# line count:  8
# line count:  10
# line count:  6
#   1%|▏         | 10/682 [00:00<00:06, 99.69it/s]
# line count:  10
# line count:  10
# line count:  8
# line count:  9
# line count:  6
# line count:  10
# line count:  8
# line count:  12
# line count:  10
# line count:  9
# line count:  9
# line count:  5
# line count:  7
# line count:  7
# line count:  6
# line count:  8
#   3%|▎         | 22/682 [00:00<00:06, 103.76it/s]
# line count:  8
# line count:  7
# line count:  7
# line count:  10
# line count:  13
# line count:  11
# line count:  14
# line count:  8
#   5%|▌         | 35/682 [00:00<00:05, 108.81it/s]
# line count:  7
# line count:  9
# line count:  10
# line count:  6
# line count:  9
# line count:  13
# line count:  8
# line count:  10
# line count:  9
# line count:  9
# line count:  10
# line count:  9
# line count:  8
# line count:  8
# line count:  10
# line count:  7
# line count:  10
#   7%|▋         | 47/682 [00:00<00:06, 103.13it/s]
# line count:  9
# line count:  8
# line count:  10
#   9%|▊         | 58/682 [00:00<00:05, 104.36it/s]
# line count:  7
# line count:  10
# line count:  10
# line count:  9
# line count:  13
# line count:  6
# line count:  7
# line count:  8
# line count:  10
# line count:  8
# line count:  7
# line count:  11
# line count:  11
# line count:  10
#  10%|▉         | 68/682 [00:00<00:05, 102.67it/s]
# line count:  9
# line count:  9
# line count:  8
# line count:  9
# line count:  9
# line count:  7
# line count:  8
#  11%|█▏        | 78/682 [00:00<00:05, 101.12it/s]
# line count:  7
# line count:  9
# line count:  8
# line count:  10
# line count:  10
# line count:  10
# line count:  8
# line count:  10
# line count:  8
# line count:  7
# line count:  5
# line count:  8
# line count:  8
# line count:  8
# line count:  8
# line count:  8
# line count:  9
# line count:  10
#  13%|█▎        | 89/682 [00:00<00:05, 102.11it/s]
# line count:  9
# line count:  10
# line count:  9
#  15%|█▍        | 100/682 [00:00<00:05, 101.92it/s]
# line count:  11
# line count:  8
# line count:  8
# line count:  8
# line count:  9
# line count:  8
# line count:  9
# line count:  9
# line count:  11
# line count:  10
# line count:  8
# line count:  8
# line count:  11
# line count:  9
# line count:  7
# line count:  8
# line count:  10
# line count:  11
# line count:  9
#  16%|█▋        | 111/682 [00:01<00:05, 103.68it/s]
# line count:  11
# line count:  9
# line count:  12
#  18%|█▊        | 122/682 [00:01<00:05, 103.17it/s]
# line count:  9
# line count:  11
# line count:  9
# line count:  10
# line count:  6
# line count:  8
# line count:  10
# line count:  10
# line count:  9
# line count:  9
# line count:  9
# line count:  7
# line count:  11
# line count:  10
# line count:  10
# line count:  10
# line count:  7
#  20%|█▉        | 133/682 [00:01<00:05, 100.73it/s]
# line count:  8
# line count:  7
# line count:  11
#  21%|██        | 143/682 [00:01<00:05, 99.23it/s]
# line count:  9
# line count:  9
# line count:  8
# line count:  9
# line count:  10
# line count:  13
# line count:  12
# line count:  11
# line count:  11
# line count:  9
# line count:  6
# line count:  8
# line count:  10
# line count:  10
# line count:  9
# line count:  11
# line count:  8
#  22%|██▏       | 153/682 [00:01<00:05, 99.08it/s]
# line count:  11
# line count:  15
# line count:  13
#  24%|██▍       | 163/682 [00:01<00:05, 99.15it/s]
# line count:  7
# line count:  13
# line count:  12
# line count:  11
# line count:  12
# line count:  13
# line count:  9
# line count:  13
# line count:  12
# line count:  11
# line count:  11
# line count:  9
# line count:  10
# line count:  11
# line count:  11
# line count:  11
# line count:  9
#  25%|██▌       | 173/682 [00:01<00:05, 99.22it/s]
# line count:  12
# line count:  13
# line count:  12
#  27%|██▋       | 184/682 [00:01<00:04, 100.45it/s]
# line count:  11
# line count:  10
# line count:  11
# line count:  10
# line count:  12
# line count:  9
# line count:  9
# line count:  9
# line count:  11
# line count:  10
# line count:  10
# line count:  11
# line count:  11
# line count:  11
# line count:  11
# line count:  13
# line count:  12
# line count:  13
# line count:  9
# line count:  10
# line count:  11
#  30%|███       | 206/682 [00:02<00:04, 101.82it/s]
# line count:  10
# line count:  10
# line count:  11
# line count:  13
# line count:  10
# line count:  10
# line count:  11
# line count:  12
# line count:  12
# line count:  12
# line count:  11
# line count:  8
# line count:  10
# line count:  10
# line count:  9
# line count:  9
# line count:  9
# line count:  11
# line count:  12
# line count:  10
# line count:  9
#  32%|███▏      | 217/682 [00:02<00:04, 100.24it/s]
# line count:  8
# line count:  10
# line count:  8
# line count:  8
# line count:  10
# line count:  10
# line count:  12
# line count:  10
# line count:  9
# line count:  10
# line count:  15
#  33%|███▎      | 228/682 [00:02<00:04, 98.26it/s]
# line count:  10
# line count:  8
# line count:  10
# line count:  10
# line count:  8
# line count:  7
# line count:  9
# line count:  9
#  35%|███▍      | 238/682 [00:02<00:04, 96.06it/s]
# line count:  9
# line count:  7
# line count:  10
# line count:  10
# line count:  12
# line count:  10
# line count:  10
# line count:  10
# line count:  8
# line count:  10
# line count:  8
# line count:  10
#  37%|███▋      | 249/682 [00:02<00:04, 99.86it/s]
# line count:  8
# line count:  12
# line count:  9
# line count:  8
# line count:  12
# line count:  11
# line count:  14
# line count:  12
# line count:  12
# line count:  16
#  38%|███▊      | 260/682 [00:02<00:04, 100.66it/s]
# line count:  8
# line count:  9
# line count:  9
# line count:  8
# line count:  10
# line count:  9
# line count:  11
# line count:  10
# line count:  8
# line count:  10
# line count:  6
#  40%|███▉      | 271/682 [00:02<00:04, 100.54it/s]
# line count:  13
# line count:  8
# line count:  9
# line count:  10
# line count:  8
# line count:  9
# line count:  9
# line count:  11
# line count:  8
#  41%|████▏     | 282/682 [00:02<00:04, 99.71it/s]
# line count:  12
# line count:  9
# line count:  13
# line count:  9
# line count:  12
# line count:  9
# line count:  10
# line count:  11
# line count:  14
# line count:  11
# line count:  10
# line count:  12
#  43%|████▎     | 293/682 [00:02<00:03, 101.77it/s]
# line count:  13
# line count:  12
# line count:  14
# line count:  10
# line count:  13
# line count:  8
# line count:  11
# line count:  9
# line count:  10
#  45%|████▍     | 304/682 [00:02<00:03, 100.78it/s]
# line count:  12
# line count:  9
# line count:  12
# line count:  9
# line count:  12
# line count:  11
# line count:  11
# line count:  10
# line count:  8
# line count:  6
# line count:  10
# line count:  10
#  46%|████▌     | 315/682 [00:03<00:03, 100.24it/s]
# line count:  7
# line count:  10
# line count:  10
# line count:  12
# line count:  13
# line count:  11
# line count:  10
# line count:  11
#  48%|████▊     | 326/682 [00:03<00:03, 100.37it/s]
# line count:  13
# line count:  7
# line count:  10
# line count:  7
# line count:  11
# line count:  9
# line count:  11
# line count:  13
# line count:  11
# line count:  12
# line count:  10
# line count:  12
# line count:  11
# line count:  7
# line count:  8
# line count:  9
# line count:  8
#  49%|████▉     | 337/682 [00:03<00:03, 98.64it/s]
# line count:  12
# line count:  12
# line count:  8
#  51%|█████     | 348/682 [00:03<00:03, 100.43it/s]
# line count:  8
# line count:  9
# line count:  10
# line count:  10
# line count:  7
# line count:  8
# line count:  6
# line count:  6
# line count:  9
# line count:  10
# line count:  7
# line count:  10
# line count:  10
# line count:  9
# line count:  9
# line count:  11
# line count:  11
# line count:  7
# line count:  8
# line count:  8
# line count:  7
#  54%|█████▍    | 370/682 [00:03<00:03, 101.32it/s]
# line count:  9
# line count:  9
# line count:  11
# line count:  10
# line count:  11
# line count:  15
# line count:  14
# line count:  12
# line count:  10
# line count:  9
# line count:  10
# line count:  8
# line count:  10
# line count:  9
# line count:  9
# line count:  8
# line count:  10
# line count:  11
# line count:  10
# line count:  10
# line count:  8
#  57%|█████▋    | 391/682 [00:03<00:02, 99.58it/s]
# line count:  8
# line count:  8
# line count:  9
# line count:  9
# line count:  9
# line count:  8
# line count:  9
# line count:  13
# line count:  11
# line count:  11
# line count:  9
# line count:  8
# line count:  9
# line count:  9
# line count:  9
# line count:  10
# line count:  6
# line count:  9
# line count:  11
# line count:  10
#  60%|██████    | 411/682 [00:04<00:02, 98.48it/s]
# line count:  9
# line count:  13
# line count:  11
# line count:  12
# line count:  9
# line count:  10
# line count:  9
# line count:  10
# line count:  8
# line count:  7
# line count:  10
# line count:  7
# line count:  9
# line count:  9
# line count:  8
# line count:  13
# line count:  7
# line count:  10
# line count:  6
# line count:  7
#  63%|██████▎   | 432/682 [00:04<00:02, 98.92it/s]
# line count:  8
# line count:  8
# line count:  8
# line count:  10
# line count:  13
# line count:  11
# line count:  12
# line count:  8
# line count:  7
# line count:  9
# line count:  9
# line count:  11
# line count:  8
# line count:  9
# line count:  8
# line count:  11
# line count:  9
# line count:  10
# line count:  9
# line count:  8
#  66%|██████▋   | 453/682 [00:04<00:02, 99.47it/s]
# line count:  8
# line count:  8
# line count:  6
# line count:  8
# line count:  7
# line count:  10
# line count:  8
# line count:  7
# line count:  7
# line count:  8
# line count:  10
# line count:  10
# line count:  10
# line count:  9
# line count:  8
# line count:  8
# line count:  11
# line count:  9
# line count:  10
# line count:  10
# line count:  11
#  68%|██████▊   | 464/682 [00:04<00:02, 99.87it/s]
# line count:  10
# line count:  11
# line count:  9
# line count:  9
# line count:  10
# line count:  8
# line count:  8
# line count:  10
# line count:  10
# line count:  9
# line count:  9
# line count:  11
# line count:  12
#  70%|██████▉   | 474/682 [00:04<00:02, 99.43it/s]
# line count:  10
# line count:  10
# line count:  8
# line count:  9
# line count:  6
# line count:  10
# line count:  8
# line count:  8
#  71%|███████   | 485/682 [00:04<00:01, 101.94it/s]
# line count:  10
# line count:  9
# line count:  8
# line count:  11
# line count:  8
# line count:  10
# line count:  11
# line count:  10
# line count:  11
# line count:  9
# line count:  9
# line count:  10
# line count:  12
#  73%|███████▎  | 496/682 [00:04<00:01, 100.93it/s]
# line count:  10
# line count:  10
# line count:  9
# line count:  11
# line count:  10
# line count:  10
# line count:  14
#  74%|███████▍  | 507/682 [00:05<00:01, 100.50it/s]
# line count:  8
# line count:  8
# line count:  10
# line count:  10
# line count:  7
# line count:  8
# line count:  10
# line count:  8
# line count:  8
# line count:  12
# line count:  13
# line count:  8
# line count:  8
#  76%|███████▌  | 518/682 [00:05<00:01, 99.76it/s]
# line count:  8
# line count:  10
# line count:  7
# line count:  9
# line count:  9
# line count:  8
# line count:  8
#  77%|███████▋  | 528/682 [00:05<00:01, 99.52it/s]
# line count:  10
# line count:  9
# line count:  10
# line count:  9
# line count:  12
# line count:  8
# line count:  8
# line count:  10
# line count:  8
# line count:  15
# line count:  12
# line count:  9
# line count:  12
# line count:  11
#  79%|███████▉  | 539/682 [00:05<00:01, 100.77it/s]
# line count:  14
# line count:  11
# line count:  12
# line count:  8
# line count:  11
# line count:  10
# line count:  8
#  81%|████████  | 550/682 [00:05<00:01, 102.09it/s]
# line count:  8
# line count:  8
# line count:  8
# line count:  10
# line count:  12
# line count:  11
# line count:  9
# line count:  10
# line count:  10
# line count:  7
# line count:  8
# line count:  8
# line count:  8
# line count:  9
#  82%|████████▏ | 561/682 [00:05<00:01, 101.30it/s]
# line count:  7
# line count:  10
# line count:  7
# line count:  10
# line count:  10
# line count:  8
# line count:  11
#  84%|████████▍ | 572/682 [00:05<00:01, 100.87it/s]
# line count:  7
# line count:  8
# line count:  9
# line count:  9
# line count:  7
# line count:  9
# line count:  8
# line count:  9
# line count:  9
# line count:  9
# line count:  10
# line count:  9
# line count:  11
# line count:  7
#  85%|████████▌ | 583/682 [00:05<00:00, 102.68it/s]
# line count:  7
# line count:  12
# line count:  13
# line count:  11
# line count:  10
# line count:  10
# line count:  14
# line count:
#  87%|████████▋ | 594/682 [00:05<00:00, 102.29it/s]
#  11
# line count:  11
# line count:  11
# line count:  11
# line count:  10
# line count:  7
# line count:  9
# line count:  9
# line count:  9
# line count:  11
# line count:  9
# line count:  10
# line count:  11
# line count:  15
#  89%|████████▊ | 605/682 [00:06<00:00, 100.81it/s]
# line count:  12
# line count:  13
# line count:  9
# line count:  11
# line count:  9
# line count:  10
#  90%|█████████ | 616/682 [00:06<00:00, 100.71it/s]
# line count:  12
# line count:  9
# line count:  9
# line count:  13
# line count:  13
# line count:  10
# line count:  9
# line count:  11
# line count:  11
# line count:  9
# line count:  9
# line count:  9
# line count:  8
# line count:  10
# line count:  12
# line count:  12
# line count:  11
# line count:  13
# line count:  10
# line count:  11
#  93%|█████████▎| 637/682 [00:06<00:00, 96.98it/s]
# line count:  9
# line count:  8
# line count:  8
# line count:  8
# line count:  10
# line count:  7
# line count:  8
# line count:  9
# line count:  7
# line count:  9
# line count:  9
# line count:  11
# line count:  9
# line count:  9
# line count:  9
# line count:  8
# line count:  7
# line count:  8
# line count:  9
# line count:  9
#  96%|█████████▋| 657/682 [00:06<00:00, 97.05it/s]
# line count:  11
# line count:  8
# line count:  10
# line count:  10
# line count:  13
# line count:  10
# line count:  7
# line count:  11
# line count:  8
# line count:  8
# line count:  10
# line count:  8
# line count:  7
# line count:  9
# line count:  7
# line count:  12
# line count:  11
# line count:  9
# line count:  10
# line count:  11
#  99%|█████████▉| 677/682 [00:06<00:00, 96.89it/s]
# line count:  10
# line count:  9
# line count:  10
# line count:  8
# line count:  9
# line count:  10
# line count:  10
# line count:  10
# line count:  12
# line count:  11
# line count:  12
# line count:  8
# line count:  9
# line count:  8
# 100%|█████████▉| 681/682 [00:06<00:00, 100.37it/s]
# line count:  8
# line count:  9
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/solidYellowLeft.mp4
#
# CPU times: user 4.92 s, sys: 1.28 s, total: 6.2 s
# Wall time: 7.02 s
# do processing:  challenge.mp4
# line count:  35
# [MoviePy] >>>> Building video test_videos_output/challenge.mp4
# [MoviePy] Writing video test_videos_output/challenge.mp4
#   0%|          | 0/251 [00:00<?, ?it/s]
# line count:  35
#   3%|▎         | 7/251 [00:00<00:03, 64.07it/s]
# line count:  33
# line count:  35
# line count:  26
# line count:  32
# line count:  35
# line count:  42
# line count:  32
# line count:  33
# line count:  35
# line count:  31
# line count:  32
# line count:  35
# line count:  43
#   6%|▌         | 14/251 [00:00<00:03, 65.63it/s]
# line count:  37
#   8%|▊         | 21/251 [00:00<00:03, 66.57it/s]
# line count:  36
# line count:  32
# line count:  29
# line count:  33
# line count:  34
# line count:  32
# line count:  36
# line count:  31
# line count:  33
# line count:  40
# line count:  34
# line count:  37
#  11%|█         | 28/251 [00:00<00:03, 66.27it/s]
# line count:  34
# line count:  35
#  14%|█▍        | 35/251 [00:00<00:03, 65.77it/s]
# line count:  42
# line count:  46
# line count:  39
# line count:  38
# line count:  38
# line count:  43
# line count:  46
# line count:  46
# line count:  44
# line count:  36
# line count:  37
# line count:  40
#  17%|█▋        | 42/251 [00:00<00:03, 65.35it/s]
# line count:  40
#  19%|█▉        | 48/251 [00:00<00:03, 59.20it/s]
# line count:  43
# line count:  36
# line count:  36
# line count:  34
# line count:  33
# line count:  31
# line count:  35
# line count:  41
# line count:  47
# line count:  41
# line count:  42
#  24%|██▍       | 60/251 [00:00<00:03, 59.00it/s]
# line count:  42
# line count:  40
# line count:  45
# line count:  42
# line count:  44
# line count:  43
# line count:  48
# line count:  43
# line count:  51
# line count:  41
# line count:  44
# line count:  40
#  29%|██▊       | 72/251 [00:01<00:03, 58.50it/s]
# line count:  41
# line count:  36
# line count:  37
# line count:  42
# line count:  38
# line count:  48
# line count:  40
# line count:  41
# line count:  47
# line count:  43
# line count:  41
# line count:  39
#  33%|███▎      | 84/251 [00:01<00:03, 55.25it/s]
# line count:  50
# line count:  52
# line count:  46
# line count:  45
# line count:  45
# line count:  41
# line count:  53
# line count:  49
# line count:  51
# line count:  59
#  38%|███▊      | 96/251 [00:01<00:02, 54.51it/s]
# line count:  70
# line count:  71
# line count:  79
# line count:  81
# line count:  93
# line count:  67
# line count:  68
# line count:  78
# line count:  71
# line count:  93
# line count:  76
#  43%|████▎     | 108/251 [00:01<00:02, 53.64it/s]
# line count:  66
# line count:  65
# line count:  57
# line count:  52
# line count:  49
# line count:  45
# line count:  46
# line count:  46
# line count:  63
# line count:  72
# line count:  79
#  45%|████▌     | 114/251 [00:01<00:02, 51.65it/s]
# line count:  74
# line count:  60
# line count:  66
# line count:  55
# line count:  41
# line count:  41
# line count:  37
# line count:  39
# line count:  36
# line count:  34
#  48%|████▊     | 120/251 [00:02<00:02, 51.98it/s]
# line count:  36
#  51%|█████     | 127/251 [00:02<00:02, 54.58it/s]
# line count:  31
# line count:  23
# line count:  25
# line count:  29
# line count:  25
# line count:  36
# line count:  33
# line count:  28
# line count:  27
# line count:  26
# line count:  34
# line count:  35
#  55%|█████▌    | 139/251 [00:02<00:02, 53.18it/s]
# line count:  31
# line count:  35
# line count:  39
# line count:  47
# line count:  35
# line count:  35
# line count:  39
# line count:  48
# line count:  50
# line count:  42
# line count:  51
#  60%|██████    | 151/251 [00:02<00:02, 49.92it/s]
# line count:  64
# line count:  72
# line count:  88
# line count:  100
# line count:  97
# line count:  83
# line count:  63
# line count:  46
# line count:  29
# line count:  39
#  65%|██████▍   | 163/251 [00:02<00:01, 51.64it/s]
# line count:  51
# line count:  39
# line count:  35
# line count:  34
# line count:  30
# line count:  21
# line count:  21
# line count:  18
# line count:  26
# line count:  17
# line count:  14
# line count:  14
#  70%|██████▉   | 175/251 [00:03<00:01, 54.81it/s]
# line count:  18
# line count:  23
# line count:  32
# line count:  34
# line count:  34
# line count:  36
# line count:  35
# line count:  30
# line count:  34
# line count:  25
# line count:  31
# line count:  27
#  72%|███████▏  | 181/251 [00:03<00:01, 54.26it/s]
# line count:  29
# line count:  32
# line count:  34
# line count:  29
# line count:  32
# line count:  34
# line count:  32
# line count:  33
# line count:  40
#  75%|███████▍  | 187/251 [00:03<00:01, 53.31it/s]
# line count:  31
#  77%|███████▋  | 193/251 [00:03<00:01, 53.96it/s]
# line count:  31
# line count:  31
# line count:  27
# line count:  36
# line count:  32
# line count:  32
# line count:  33
# line count:  27
# line count:  29
# line count:  40
# line count:  32
#  82%|████████▏ | 205/251 [00:03<00:00, 52.24it/s]
# line count:  38
# line count:  34
# line count:  30
# line count:  33
# line count:  29
# line count:  36
# line count:  25
# line count:  29
# line count:  33
# line count:  32
# line count:
#  87%|████████▋ | 218/251 [00:03<00:00, 54.95it/s]
# 34
# line count:  33
# line count:  29
# line count:  39
# line count:  31
# line count:  41
# line count:  38
# line count:  29
# line count:  26
# line count:  34
# line count:  33
# line count:  38
#  92%|█████████▏| 230/251 [00:04<00:00, 54.72it/s]
# line count:  38
# line count:  30
# line count:  32
# line count:  33
# line count:  29
# line count:  30
# line count:  31
# line count:  31
# line count:  32
# line count:  33
# line count:  30
# line count:  32
#  96%|█████████▋| 242/251 [00:04<00:00, 55.62it/s]
# line count:  30
# line count:  28
# line count:  30
# line count:  28
# line count:  30
# line count:  34
# line count:  31
# line count:  29
# line count:  36
# line count:  27
# line count:  30
# 100%|██████████| 251/251 [00:04<00:00, 55.81it/s]
# line count:  35
# line count:  30
# line count:  34
# line count:  33
# line count:  34
# line count:  31
# line count:  28
# line count:  25
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/challenge.mp4
#
# CPU times: user 3.71 s, sys: 688 ms, total: 4.4 s
# Wall time: 4.96 s

# %% [markdown]
# Play the video inline, or if you prefer find the video in your filesystem (should be in the same directory) and play it in your video player of choice.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/challenge.mp4">
# </video>

# %% [markdown]
# ## Improve the draw_lines() function
#
# **At this point, if you were successful with making the pipeline and tuning parameters, you probably have the Hough line segments drawn onto the road, but what about identifying the full extent of the lane and marking it clearly as in the example video (P1_example.mp4)?  Think about defining a line to run the full length of the visible lane based on the line segments you identified with the Hough Transform. As mentioned previously, try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines. You can see an example of the result you're going for in the video "P1_example.mp4".**
#
# **Go back and modify your draw_lines function accordingly and try re-running your pipeline. The new output should draw a single, solid line over the left lane line and a single, solid line over the right lane line. The lines should start from the bottom of the image and extend out to the top of the region of interest.**

# %% [markdown]
# Now for the one with the solid yellow lane on the left. This one's more tricky!

# %%
yellow_output = 'test_videos_output/solidYellowLeft.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4').subclip(0,5)
clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4')
yellow_clip = clip2.fl_image(process_image)
# %time yellow_clip.write_videofile(yellow_output, audio=False)

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(yellow_output))

# %% [markdown]
# ## Writeup and Submission
#
# If you're satisfied with your video outputs, it's time to make the report writeup in a pdf or markdown file. Once you have this Ipython notebook ready along with the writeup, it's time to submit for review! Here is a [link](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) to the writeup template file.

# %% [markdown]
# ## Optional Challenge
#
# Try your lane finding pipeline on the video below.  Does it still work?  Can you figure out a way to make it more robust?  If you're up for the challenge, modify your pipeline so it works with this video and submit it along with the rest of your project!

# %%
def process_challenge_image(image):
    global count
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image where lines are drawn on lanes)
    result,_ = find_lane_lines(image, challenge_canny_low_threshold, challenge_canny_high_threshold, challenge_hough_min_line_length)
#     count = count + 1
#     if count % 50 == 0:
#         mpimg.imsave('test_challenge_images/%05d.jpg' % count, image)
    return result

challenge_output = 'test_videos_output/challenge.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip3 = VideoFileClip('test_videos/challenge.mp4').subclip(0,5)
clip3 = VideoFileClip('test_videos/challenge.mp4')
challenge_clip = clip3.fl_image(process_image)
# %time challenge_clip.write_videofile(challenge_output, audio=False)
# Out:
# [MoviePy] >>>> Building video test_videos_output/challenge.mp4
# [MoviePy] Writing video test_videos_output/challenge.mp4
#   0%|          | 0/251 [00:00<?, ?it/s]
#   3%|▎         | 7/251 [00:00<00:03, 69.83it/s]
#   6%|▌         | 15/251 [00:00<00:03, 70.16it/s]
#   9%|▉         | 23/251 [00:00<00:03, 70.91it/s]
#  12%|█▏        | 31/251 [00:00<00:03, 70.91it/s]
#  16%|█▌        | 39/251 [00:00<00:02, 70.96it/s]
#  18%|█▊        | 46/251 [00:00<00:02, 69.99it/s]
#  21%|██        | 53/251 [00:00<00:03, 62.14it/s]
#  24%|██▎       | 59/251 [00:00<00:03, 59.53it/s]
#  26%|██▌       | 65/251 [00:01<00:03, 56.01it/s]
#  28%|██▊       | 71/251 [00:01<00:03, 54.99it/s]
#  31%|███       | 77/251 [00:01<00:03, 54.39it/s]
#  33%|███▎      | 83/251 [00:01<00:03, 53.78it/s]
#  35%|███▌      | 89/251 [00:01<00:03, 53.59it/s]
#  38%|███▊      | 95/251 [00:01<00:02, 53.22it/s]
#  40%|████      | 101/251 [00:01<00:02, 52.92it/s]
#  43%|████▎     | 107/251 [00:01<00:02, 54.72it/s]
#  45%|████▌     | 113/251 [00:01<00:02, 50.96it/s]
#  47%|████▋     | 119/251 [00:02<00:02, 51.20it/s]
#  50%|████▉     | 125/251 [00:02<00:02, 50.89it/s]
#  52%|█████▏    | 131/251 [00:02<00:02, 49.87it/s]
#  55%|█████▍    | 137/251 [00:02<00:02, 48.32it/s]
#  57%|█████▋    | 142/251 [00:02<00:02, 46.84it/s]
#  59%|█████▊    | 147/251 [00:02<00:02, 45.56it/s]
#  61%|██████    | 153/251 [00:02<00:02, 47.43it/s]
#  63%|██████▎   | 159/251 [00:02<00:01, 49.41it/s]
#  66%|██████▌   | 165/251 [00:03<00:01, 51.05it/s]
#  68%|██████▊   | 171/251 [00:03<00:01, 53.28it/s]
#  71%|███████   | 177/251 [00:03<00:01, 53.59it/s]
#  73%|███████▎  | 183/251 [00:03<00:01, 52.58it/s]
#  75%|███████▌  | 189/251 [00:03<00:01, 49.94it/s]
#  78%|███████▊  | 195/251 [00:03<00:01, 50.68it/s]
#  80%|████████  | 201/251 [00:03<00:00, 50.77it/s]
#  82%|████████▏ | 207/251 [00:03<00:00, 50.61it/s]
#  85%|████████▍ | 213/251 [00:03<00:00, 51.61it/s]
#  87%|████████▋ | 219/251 [00:04<00:00, 51.64it/s]
#  90%|████████▉ | 225/251 [00:04<00:00, 52.04it/s]
#  92%|█████████▏| 231/251 [00:04<00:00, 52.39it/s]
#  94%|█████████▍| 237/251 [00:04<00:00, 52.41it/s]
#  97%|█████████▋| 243/251 [00:04<00:00, 52.35it/s]
# 100%|█████████▉| 250/251 [00:04<00:00, 54.83it/s]
# 100%|██████████| 251/251 [00:04<00:00, 54.16it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/challenge.mp4
#
# CPU times: user 4.29 s, sys: 0 ns, total: 4.29 s
# Wall time: 5.16 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/challenge.mp4">
# </video>
